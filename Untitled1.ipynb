# %%
import pandas as pd
# Créer un DataFrame à partir d'un dictionnaire
data = {
'Nom': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
'Age': [25, 30, 35, 28, 22],
'Ville': ['Paris', 'Lyon', 'Paris', 'Marseille', 'Lyon'],
'Salaire': [45000, 55000, 60000, 48000, 42000],
'Experience': [2, 5, 8, 4, 1]
}

df = pd.DataFrame(data)
print("Notre DataFrame :")
df
# Out:
# Notre DataFrame :
#        Nom  Age      Ville  Salaire  Experience
# 0    Alice   25      Paris    45000           2
# 1      Bob   30       Lyon    55000           5
# 2  Charlie   35      Paris    60000           8
# 3    Diana   28  Marseille    48000           4
# 4      Eve   22       Lyon    42000           1

# %%
import pandas as pd
# Données
produits = ['Laptop', 'Smartphone', 'Tablette', 'Écouteurs', 'Souris', 'Clavier']
prix = [999, 699, 449, 149, 29, 79]
stock = [50, 120, 75, 200, 500, 300]
categorie = ['Informatique', 'Mobile', 'Mobile', 'Audio', 'Accessoire', 'Accessoire']
# Création du DataFrame
df_produit2 = pd.DataFrame({
    'Produit': produits,
    'Prix': prix,
    'Stock': stock,
    'Catégorie': categorie
})
df_produit2
df_produit2.shape
df_produit2.head(2)
df_produit2.tail(3)
df_produit2.describe()
# Out:
#              Prix       Stock
# count    6.000000    6.000000
# mean   400.666667  207.500000
# std    388.402712  169.816077
# min     29.000000   50.000000
# 25%     96.500000   86.250000
# 50%    299.000000  160.000000
# 75%    636.500000  275.000000
# max    999.000000  500.000000

# %%
df_produit3 = None
import pandas as pd

# Données
produit3 = ['Laptop', 'Smartphone', 'Tablette', 'Écouteurs', 'Souris', 'Clavier']
prix3 = [999, 699, 449, 149, 29, 79]
stock3 = [50, 120, 75, 200, 500, 300]
categorie3 = ['Informatique', 'Mobile', 'Mobile', 'Audio', 'Accessoire', 'Accessoire']

# Création du DataFrame
df_produit3 = pd.DataFrame({
    'Produit': produit3,
    'Prix': prix3,
    'Stock': stock3,
    'Catégorie': categorie3
})

# Affichez le DataFrame
df_produit3

# Afficher la taille
df_produit3.shape
# Afficher les types
df_produit3.dtypes
# Afficher les 2 permières ligne et les 3 dernieres lignes
df_produit3.head(2)
df_produit3.tail(3)
# Affichers les statistiques descriptives
df_produit3.tail(3)
# Out:
#      Produit  Prix  Stock   Catégorie
# 3  Écouteurs   149    200       Audio
# 4     Souris    29    500  Accessoire
# 5    Clavier    79    300  Accessoire
